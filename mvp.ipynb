# %% [markdown]
# Emotion Detection

# %%
import cv2
from deepface import DeepFace
import time

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame")
        break
        
    try:
        # Add a small delay to reduce processing load
        time.sleep(0.1)
        
        # Detect emotion
        results = DeepFace.analyze(
            img_path=frame,
            actions=['emotion'],
            enforce_detection=False,
            detector_backend='opencv'
        )
        
        dominant_emotion = results[0]['dominant_emotion']
        
        # Display detected emotion
        cv2.putText(frame, dominant_emotion, (50, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
    except Exception as e:
        print(f"Error occurred: {str(e)}")
        cv2.putText(frame, "Processing...", (50, 50), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    cv2.imshow("Emotion Detection", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From c:\Users\sriva\OneDrive\Learning\Deep Learning\EmoArt-GenAI-Vision\emoart_env\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'
# Error occurred: module 'deepface.modules.modeling' has no attribute 'build_model'

# %%
import cv2
from deepface import DeepFace

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Detect emotion
    results = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
    dominant_emotion = results[0]['dominant_emotion']
    
    # Display detected emotion
    cv2.putText(frame, dominant_emotion, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.imshow("Emotion Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 13
#      10     break
#      12 # Detect emotion
# ---> 13 results = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
#      14 dominant_emotion = results[0]['dominant_emotion']
#      16 # Display detected emotion
#
# File c:\Users\sriva\OneDrive\Learning\Deep Learning\EmoArt-GenAI-Vision\emoart_env\lib\site-packages\deepface\DeepFace.py:253, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     166 def analyze(
#     167     img_path: Union[str, np.ndarray],
#     168     actions: Union[tuple, list] = ("emotion", "age", "gender", "race"),
#    (...)
#     174     anti_spoofing: bool = False,
#     175 ) -> List[Dict[str, Any]]:
#     176     """
#     177     Analyze facial attributes such as age, gender, emotion, and race in the provided image.
#     178     Args:
#    (...)
#     251             - 'white': Confidence score for White ethnicity.
#     252     """
# --> 253     return demography.analyze(
#     254         img_path=img_path,
#     255         actions=actions,
#     256         enforce_detection=enforce_detection,
#     257         detector_backend=detector_backend,
#     258         align=align,
#     259         expand_percentage=expand_percentage,
#     260         silent=silent,
#     261         anti_spoofing=anti_spoofing,
#     262     )
#
# File c:\Users\sriva\OneDrive\Learning\Deep Learning\EmoArt-GenAI-Vision\emoart_env\lib\site-packages\deepface\modules\demography.py:123, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     120 # ---------------------------------
#     121 resp_objects = []
# --> 123 img_objs = detection.extract_faces(
#     124     img_path=img_path,
#     125     detector_backend=detector_backend,
#     126     enforce_detection=enforce_detection,
#     127     grayscale=False,
#     128     align=align,
#     129     expand_percentage=expand_percentage,
#     130     anti_spoofing=anti_spoofing,
#     131 )
#     133 for img_obj in img_objs:
#     134     if anti_spoofing is True and img_obj.get("is_real", True) is False:
#
# File c:\Users\sriva\OneDrive\Learning\Deep Learning\EmoArt-GenAI-Vision\emoart_env\lib\site-packages\deepface\modules\detection.py:95, in extract_faces(img_path, detector_backend, enforce_detection, align, expand_percentage, grayscale, color_face, normalize_face, anti_spoofing)
#      93     face_objs = [DetectedFace(img=img, facial_area=base_region, confidence=0)]
#      94 else:
# ---> 95     face_objs = detect_faces(
#      96         detector_backend=detector_backend,
#      97         img=img,
#      98         align=align,
#      99         expand_percentage=expand_percentage,
#     100     )
#     102 # in case of no face found
#     103 if len(face_objs) == 0 and enforce_detection is True:
#
# File c:\Users\sriva\OneDrive\Learning\Deep Learning\EmoArt-GenAI-Vision\emoart_env\lib\site-packages\deepface\modules\detection.py:206, in detect_faces(detector_backend, img, align, expand_percentage)
#     181 """
#     182 Detect face(s) from a given image
#     183 Args:
#    (...)
#     202     - confidence (float): The confidence score associated with the detected face.
#     203 """
#     204 height, width, _ = img.shape
# --> 206 face_detector: Detector = modeling.build_model(
#     207     task="face_detector", model_name=detector_backend
#     208 )
#     210 # validate expand percentage score
#     211 if expand_percentage < 0:
#
# AttributeError: module 'deepface.modules.modeling' has no attribute 'build_model'
